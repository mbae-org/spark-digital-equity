# %%
# Digital Equity

# %%
import pandas as pd
import numpy as np

# %%
course_enrollment = pd.read_csv('initial_data/CS Course Enrollment 2018.csv')

# %%
course_enrollment
# Out:
#       School Code                                           District  \
# 0           10015                                           Abington
# 1           10020                                           Abington
# 2           10405                                           Abington
# 3           10505                                           Abington
# 4           30025                                           Acushnet
# ...           ...                                                ...
# 1224     35130305  New Heights Charter School of Brockton (District)
# 1225     35140305         Libertas Academy Charter School (District)
# 1226     39010900           Greenfield Commonwealth Virtual District
# 1227     39020900  TEC Connections Academy Commonwealth Virtual S...
# 1228            0                                      Massachusetts
#
#                                             School Name  # STUDENTS ENROLLED   \
# 0                           Woodsdale Elementary School                     2
# 1                               Beaver Brook Elementary                     3
# 2                                Abington Middle School                   348
# 3                                         Abington High                    25
# 4                            Acushnet Elementary School                   105
# ...                                                 ...                   ...
# 1224             New Heights Charter School of Brockton                    14
# 1225                    Libertas Academy Charter School                    70
# 1226             Greenfield Commonwealth Virtual School                    21
# 1227  TEC Connections Academy Commonwealth Virtual S...                   681
# 1228                                      Massachusetts                235211
#
#       # STUDENTS ENROLLED PRIOR TO SECONDARY LEVEL  \
# 0                                                2
# 1                                                3
# 2                                              348
# 3                                                0
# 4                                              105
# ...                                            ...
# 1224                                            11
# 1225                                            70
# 1226                                             9
# 1227                                           521
# 1228                                        199273
#
#       # STUDENTS ENROLLED AT SECONDARY LEVEL
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                         25
# 4                                          0
# ...                                      ...
# 1224                                       3
# 1225                                       0
# 1226                                      12
# 1227                                     160
# 1228                                   36137
#
# [1229 rows x 6 columns]

# %%
course_enrollment = course_enrollment.drop(columns=["# STUDENTS ENROLLED PRIOR TO SECONDARY LEVEL", "# STUDENTS ENROLLED AT SECONDARY LEVEL"])

# %%
course_enrollment.dtypes
# Out:
# School Code              int64
# District                object
# School Name             object
# # STUDENTS ENROLLED      int64
# dtype: object

# %%
course_enrollment
# Out:
#       School Code                                           District  \
# 0           10015                                           Abington
# 1           10020                                           Abington
# 2           10405                                           Abington
# 3           10505                                           Abington
# 4           30025                                           Acushnet
# ...           ...                                                ...
# 1224     35130305  New Heights Charter School of Brockton (District)
# 1225     35140305         Libertas Academy Charter School (District)
# 1226     39010900           Greenfield Commonwealth Virtual District
# 1227     39020900  TEC Connections Academy Commonwealth Virtual S...
# 1228            0                                      Massachusetts
#
#                                             School Name  # STUDENTS ENROLLED
# 0                           Woodsdale Elementary School                     2
# 1                               Beaver Brook Elementary                     3
# 2                                Abington Middle School                   348
# 3                                         Abington High                    25
# 4                            Acushnet Elementary School                   105
# ...                                                 ...                   ...
# 1224             New Heights Charter School of Brockton                    14
# 1225                    Libertas Academy Charter School                    70
# 1226             Greenfield Commonwealth Virtual School                    21
# 1227  TEC Connections Academy Commonwealth Virtual S...                   681
# 1228                                      Massachusetts                235211
#
# [1229 rows x 4 columns]

# %%
demographic = pd.read_csv('initial_data/AP CS Gender Ethnicity 2018.csv')

# %%
demographic
# Out:
#      ORG_CODE  School Code                                          DIST_NAME  \
# 0           9        90505                                            Andover
# 1          10       100505                                          Arlington
# 2          14       140505                                            Ashland
# 3          16       160505                                          Attleboro
# 4          17       170505                                             Auburn
# ..        ...          ...                                                ...
# 132       818      8180605      Franklin County Regional Vocational Technical
# 133       828      8280605       Greater Lowell Regional Vocational Technical
# 134       829      8290605      South Middlesex Regional Vocational Technical
# 135      3506     35060505  Pioneer Charter School of Science II (PCSS-II)...
# 136         0            0                                      Massachusetts
#
#                                            SCH_NAME  STUDENTS_ENROLLED   AA  \
# 0                                      Andover High                 39    1
# 1                                    Arlington High                 17    0
# 2                                      Ashland High                 26    0
# 3                                    Attleboro High                 17    1
# 4                                Auburn Senior High                 10    0
# ..                                              ...                ...  ...
# 132                       Franklin County Technical                  6    0
# 133         Gr Lowell Regional Vocational Technical                 26    0
# 134            Joseph P Keefe Technical High School                 14    1
# 135  Pioneer Charter School of Science II (PCSS-II)                  5
# 136                                   Massachusetts               2629  162
#
#       AS   HI  MR NA NH_PI    WH EcoDis SWD ELL FEMALE  MALE NONBINARY
# 0     17    0   1  0     0    20      1   2   0      6    33         0
# 1      6    0   0  0     0    11      0   1   0      2    15         0
# 2      6    0   0  0     0    20      0   1   0      9    17         0
# 3      0    0   2  0     0    14      1   0   0      3    14         0
# 4      1    0   0  0     0     9      0   0   0      2     8         0
# ..   ...  ...  .. ..   ...   ...    ...  ..  ..    ...   ...       ...
# 132    0    1   0  0     0     5      4   2   0      2     4         0
# 133    3    4   2  0     0    17      9   2   0      6    20         0
# 134    0    4   0  0     0     9      4   3   0      2    12         0
# 135
# 136  488  168  81  4     2  1667    281  82  13    679  1893         0
#
# [137 rows x 18 columns]

# %%
demographic.dtypes
# Out:
# ORG_CODE              int64
# School Code           int64
# DIST_NAME            object
# SCH_NAME             object
# STUDENTS_ENROLLED     int64
# AA                   object
# AS                   object
# HI                   object
# MR                   object
# NA                   object
# NH_PI                object
# WH                   object
# EcoDis               object
# SWD                  object
# ELL                  object
# FEMALE               object
# MALE                 object
# NONBINARY            object
# dtype: object

# %%
demographic = demographic.drop(columns=['DIST_NAME', 'SCH_NAME'])

# %%
demographic
# Out:
#      ORG_CODE  School Code  STUDENTS_ENROLLED   AA   AS   HI  MR NA NH_PI  \
# 0           9        90505                 39    1   17    0   1  0     0
# 1          10       100505                 17    0    6    0   0  0     0
# 2          14       140505                 26    0    6    0   0  0     0
# 3          16       160505                 17    1    0    0   2  0     0
# 4          17       170505                 10    0    1    0   0  0     0
# ..        ...          ...                ...  ...  ...  ...  .. ..   ...
# 132       818      8180605                  6    0    0    1   0  0     0
# 133       828      8280605                 26    0    3    4   2  0     0
# 134       829      8290605                 14    1    0    4   0  0     0
# 135      3506     35060505                  5
# 136         0            0               2629  162  488  168  81  4     2
#
#        WH EcoDis SWD ELL FEMALE  MALE NONBINARY
# 0      20      1   2   0      6    33         0
# 1      11      0   1   0      2    15         0
# 2      20      0   1   0      9    17         0
# 3      14      1   0   0      3    14         0
# 4       9      0   0   0      2     8         0
# ..    ...    ...  ..  ..    ...   ...       ...
# 132     5      4   2   0      2     4         0
# 133    17      9   2   0      6    20         0
# 134     9      4   3   0      2    12         0
# 135
# 136  1667    281  82  13    679  1893         0
#
# [137 rows x 16 columns]

# %%
demographic["AA"] = pd.to_numeric(demographic["AA"], errors='coerce')
demographic["AS"] = pd.to_numeric(demographic["AS"], errors='coerce')
demographic["HI"] = pd.to_numeric(demographic["HI"], errors='coerce')
demographic["MR"] = pd.to_numeric(demographic["MR"], errors='coerce')
demographic["NA"] = pd.to_numeric(demographic["NA"], errors='coerce')
demographic["NH_PI"] = pd.to_numeric(demographic["NH_PI"], errors='coerce')
demographic["WH"] = pd.to_numeric(demographic["WH"], errors='coerce')
demographic["EcoDis"] = pd.to_numeric(demographic["EcoDis"], errors='coerce')
demographic["SWD"] = pd.to_numeric(demographic["SWD"], errors='coerce')
demographic["ELL"] = pd.to_numeric(demographic["ELL"], errors='coerce')
demographic["FEMALE"] = pd.to_numeric(demographic["FEMALE"], errors='coerce')
demographic["MALE"] = pd.to_numeric(demographic["MALE"], errors='coerce')
demographic["NONBINARY"] = pd.to_numeric(demographic["NONBINARY"], errors='coerce')

# %%
demographic["AA"] = demographic["AA"].astype("Int64")
demographic["AS"] = demographic["AS"].astype("Int64")
demographic["HI"] = demographic["HI"].astype("Int64")
demographic["MR"] = demographic["MR"].astype("Int64")
demographic["NA"] = demographic["NA"].astype("Int64")
demographic["NH_PI"] = demographic["NH_PI"].astype("Int64")
demographic["WH"] = demographic["WH"].astype("Int64")
demographic["EcoDis"] = demographic["EcoDis"].astype("Int64")
demographic["SWD"] = demographic["SWD"].astype("Int64")
demographic["ELL"] = demographic["ELL"].astype("Int64")
demographic["FEMALE"] = demographic["FEMALE"].astype("Int64")
demographic["MALE"] = demographic["MALE"].astype("Int64")
demographic["NONBINARY"] = demographic["NONBINARY"].astype("Int64")

# %%
demographic.dtypes
# Out:
# ORG_CODE             int64
# School Code          int64
# STUDENTS_ENROLLED    int64
# AA                   Int64
# AS                   Int64
# HI                   Int64
# MR                   Int64
# NA                   Int64
# NH_PI                Int64
# WH                   Int64
# EcoDis               Int64
# SWD                  Int64
# ELL                  Int64
# FEMALE               Int64
# MALE                 Int64
# NONBINARY            Int64
# dtype: object

# %%
scores = pd.read_csv('initial_data/ap_performance-2018.csv')

# %%
scores
# Out:
#                                            School Name  School Code  \
# 0                             Abington - Abington High        10505
# 1    Acton-Boxborough - Acton-Boxborough Regional High      6000505
# 2    Advanced Math and Science Academy Charter (Dis...      4300305
# 3                               Andover - Andover High        90505
# 4                           Arlington - Arlington High       100505
# ..                                                 ...          ...
# 143                    Winthrop - Winthrop High School      3460505
# 144                  Worcester - Doherty Memorial High      3480512
# 145                             Worcester - North High      3480515
# 146               Worcester - Worcester Technical High      3480605
# 147                                      Massachusetts            0
#
#      Tests Taken  Score=1  Score=2  Score=3  Score=4  Score=5  % Score 1-2  \
# 0              1      NaN      NaN      NaN      NaN      NaN          NaN
# 1             70      0.0      1.0     16.0     19.0     34.0          1.4
# 2             36      0.0      0.0      5.0     13.0     18.0          0.0
# 3             21      0.0      1.0      2.0      2.0     16.0          4.8
# 4             18      0.0      0.0      2.0      3.0     13.0          0.0
# ..           ...      ...      ...      ...      ...      ...          ...
# 143            2      NaN      NaN      NaN      NaN      NaN          NaN
# 144            6      NaN      NaN      NaN      NaN      NaN          NaN
# 145           19     18.0      0.0      1.0      0.0      0.0         94.7
# 146           18     10.0      2.0      3.0      2.0      1.0         66.7
# 147         1792    297.0    152.0    303.0    345.0    434.0       2360.3
#
#      % Score 3-5
# 0            NaN
# 1           98.6
# 2          100.0
# 3           95.2
# 4          100.0
# ..           ...
# 143          NaN
# 144          NaN
# 145          5.3
# 146         33.3
# 147       4239.8
#
# [148 rows x 10 columns]

# %%
scores = scores.drop(columns=['School Name', '% Score 1-2', '% Score 3-5'])

# %%
scores.dtypes
# Out:
# School Code      int64
# Tests Taken      int64
# Score=1        float64
# Score=2        float64
# Score=3        float64
# Score=4        float64
# Score=5        float64
# dtype: object

# %%
all_merged = course_enrollment.merge(demographic, how='left', on='School Code').merge(scores, how='left', on='School Code')

# %%
all_merged
# Out:
#       School Code                                           District  \
# 0           10015                                           Abington
# 1           10020                                           Abington
# 2           10405                                           Abington
# 3           10505                                           Abington
# 4           30025                                           Acushnet
# ...           ...                                                ...
# 1224     35130305  New Heights Charter School of Brockton (District)
# 1225     35140305         Libertas Academy Charter School (District)
# 1226     39010900           Greenfield Commonwealth Virtual District
# 1227     39020900  TEC Connections Academy Commonwealth Virtual S...
# 1228            0                                      Massachusetts
#
#                                             School Name  # STUDENTS ENROLLED   \
# 0                           Woodsdale Elementary School                     2
# 1                               Beaver Brook Elementary                     3
# 2                                Abington Middle School                   348
# 3                                         Abington High                    25
# 4                            Acushnet Elementary School                   105
# ...                                                 ...                   ...
# 1224             New Heights Charter School of Brockton                    14
# 1225                    Libertas Academy Charter School                    70
# 1226             Greenfield Commonwealth Virtual School                    21
# 1227  TEC Connections Academy Commonwealth Virtual S...                   681
# 1228                                      Massachusetts                235211
#
#       ORG_CODE  STUDENTS_ENROLLED    AA    AS    HI    MR  ...   ELL  FEMALE  \
# 0          NaN                NaN  <NA>  <NA>  <NA>  <NA>  ...  <NA>    <NA>
# 1          NaN                NaN  <NA>  <NA>  <NA>  <NA>  ...  <NA>    <NA>
# 2          NaN                NaN  <NA>  <NA>  <NA>  <NA>  ...  <NA>    <NA>
# 3          NaN                NaN  <NA>  <NA>  <NA>  <NA>  ...  <NA>    <NA>
# 4          NaN                NaN  <NA>  <NA>  <NA>  <NA>  ...  <NA>    <NA>
# ...        ...                ...   ...   ...   ...   ...  ...   ...     ...
# 1224       NaN                NaN  <NA>  <NA>  <NA>  <NA>  ...  <NA>    <NA>
# 1225       NaN                NaN  <NA>  <NA>  <NA>  <NA>  ...  <NA>    <NA>
# 1226       NaN                NaN  <NA>  <NA>  <NA>  <NA>  ...  <NA>    <NA>
# 1227       NaN                NaN  <NA>  <NA>  <NA>  <NA>  ...  <NA>    <NA>
# 1228       0.0             2629.0   162   488   168    81  ...    13     679
#
#       MALE  NONBINARY  Tests Taken  Score=1  Score=2  Score=3  Score=4  \
# 0     <NA>       <NA>          NaN      NaN      NaN      NaN      NaN
# 1     <NA>       <NA>          NaN      NaN      NaN      NaN      NaN
# 2     <NA>       <NA>          NaN      NaN      NaN      NaN      NaN
# 3     <NA>       <NA>          1.0      NaN      NaN      NaN      NaN
# 4     <NA>       <NA>          NaN      NaN      NaN      NaN      NaN
# ...    ...        ...          ...      ...      ...      ...      ...
# 1224  <NA>       <NA>          NaN      NaN      NaN      NaN      NaN
# 1225  <NA>       <NA>          NaN      NaN      NaN      NaN      NaN
# 1226  <NA>       <NA>          NaN      NaN      NaN      NaN      NaN
# 1227  <NA>       <NA>          NaN      NaN      NaN      NaN      NaN
# 1228  1893          0       1792.0    297.0    152.0    303.0    345.0
#
#       Score=5
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 1224      NaN
# 1225      NaN
# 1226      NaN
# 1227      NaN
# 1228    434.0
#
# [1229 rows x 25 columns]

# %%
all_merged.dtypes
# Out:
# School Code               int64
# District                 object
# School Name              object
# # STUDENTS ENROLLED       int64
# ORG_CODE                float64
# STUDENTS_ENROLLED       float64
# AA                        Int64
# AS                        Int64
# HI                        Int64
# MR                        Int64
# NA                        Int64
# NH_PI                     Int64
# WH                        Int64
# EcoDis                    Int64
# SWD                       Int64
# ELL                       Int64
# FEMALE                    Int64
# MALE                      Int64
# NONBINARY                 Int64
# Tests Taken             float64
# Score=1                 float64
# Score=2                 float64
# Score=3                 float64
# Score=4                 float64
# Score=5                 float64
# dtype: object

# %%
all_merged = all_merged.astype({"STUDENTS_ENROLLED": "Int64", "ORG_CODE": "Int64"})

# %%
all_merged["Tests Taken"] = all_merged["Tests Taken"].astype("Int64")
all_merged["Score=1"] = all_merged["Score=1"].astype("Int64")
all_merged["Score=2"] = all_merged["Score=2"].astype("Int64")
all_merged["Score=3"] = all_merged["Score=3"].astype("Int64")
all_merged["Score=4"] = all_merged["Score=4"].astype("Int64")
all_merged["Score=5"] = all_merged["Score=5"].astype("Int64")

# %%
all_merged.dtypes
# Out:
# School Code              int64
# District                object
# School Name             object
# # STUDENTS ENROLLED      int64
# ORG_CODE                 Int64
# STUDENTS_ENROLLED        Int64
# AA                       Int64
# AS                       Int64
# HI                       Int64
# MR                       Int64
# NA                       Int64
# NH_PI                    Int64
# WH                       Int64
# EcoDis                   Int64
# SWD                      Int64
# ELL                      Int64
# FEMALE                   Int64
# MALE                     Int64
# NONBINARY                Int64
# Tests Taken              Int64
# Score=1                  Int64
# Score=2                  Int64
# Score=3                  Int64
# Score=4                  Int64
# Score=5                  Int64
# dtype: object

# %%
all_merged['SY'] = 2017

# %%
all_merged
# Out:
#       School Code                                           District  \
# 0           10015                                           Abington
# 1           10020                                           Abington
# 2           10405                                           Abington
# 3           10505                                           Abington
# 4           30025                                           Acushnet
# ...           ...                                                ...
# 1224     35130305  New Heights Charter School of Brockton (District)
# 1225     35140305         Libertas Academy Charter School (District)
# 1226     39010900           Greenfield Commonwealth Virtual District
# 1227     39020900  TEC Connections Academy Commonwealth Virtual S...
# 1228            0                                      Massachusetts
#
#                                             School Name  # STUDENTS ENROLLED   \
# 0                           Woodsdale Elementary School                     2
# 1                               Beaver Brook Elementary                     3
# 2                                Abington Middle School                   348
# 3                                         Abington High                    25
# 4                            Acushnet Elementary School                   105
# ...                                                 ...                   ...
# 1224             New Heights Charter School of Brockton                    14
# 1225                    Libertas Academy Charter School                    70
# 1226             Greenfield Commonwealth Virtual School                    21
# 1227  TEC Connections Academy Commonwealth Virtual S...                   681
# 1228                                      Massachusetts                235211
#
#       ORG_CODE  STUDENTS_ENROLLED    AA    AS    HI    MR  ...  FEMALE  MALE  \
# 0         <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 1         <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 2         <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 3         <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 4         <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# ...        ...                ...   ...   ...   ...   ...  ...     ...   ...
# 1224      <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 1225      <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 1226      <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 1227      <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 1228         0               2629   162   488   168    81  ...     679  1893
#
#       NONBINARY  Tests Taken  Score=1  Score=2  Score=3  Score=4  Score=5  \
# 0          <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>
# 1          <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>
# 2          <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>
# 3          <NA>            1     <NA>     <NA>     <NA>     <NA>     <NA>
# 4          <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>
# ...         ...          ...      ...      ...      ...      ...      ...
# 1224       <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>
# 1225       <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>
# 1226       <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>
# 1227       <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>
# 1228          0         1792      297      152      303      345      434
#
#         SY
# 0     2017
# 1     2017
# 2     2017
# 3     2017
# 4     2017
# ...    ...
# 1224  2017
# 1225  2017
# 1226  2017
# 1227  2017
# 1228  2017
#
# [1229 rows x 26 columns]

# %%
all_merged
# Out:
#       School Code                                           District  \
# 0           10015                                           Abington
# 1           10020                                           Abington
# 2           10405                                           Abington
# 3           10505                                           Abington
# 4           30025                                           Acushnet
# ...           ...                                                ...
# 1224     35130305  New Heights Charter School of Brockton (District)
# 1225     35140305         Libertas Academy Charter School (District)
# 1226     39010900           Greenfield Commonwealth Virtual District
# 1227     39020900  TEC Connections Academy Commonwealth Virtual S...
# 1228            0                                      Massachusetts
#
#                                             School Name  # STUDENTS ENROLLED   \
# 0                           Woodsdale Elementary School                     2
# 1                               Beaver Brook Elementary                     3
# 2                                Abington Middle School                   348
# 3                                         Abington High                    25
# 4                            Acushnet Elementary School                   105
# ...                                                 ...                   ...
# 1224             New Heights Charter School of Brockton                    14
# 1225                    Libertas Academy Charter School                    70
# 1226             Greenfield Commonwealth Virtual School                    21
# 1227  TEC Connections Academy Commonwealth Virtual S...                   681
# 1228                                      Massachusetts                235211
#
#       ORG_CODE  STUDENTS_ENROLLED    AA    AS    HI    MR  ...  FEMALE  MALE  \
# 0         <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 1         <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 2         <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 3         <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 4         <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# ...        ...                ...   ...   ...   ...   ...  ...     ...   ...
# 1224      <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 1225      <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 1226      <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 1227      <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 1228         0               2629   162   488   168    81  ...     679  1893
#
#       NONBINARY  Tests Taken  Score=1  Score=2  Score=3  Score=4  Score=5  \
# 0          <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>
# 1          <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>
# 2          <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>
# 3          <NA>            1     <NA>     <NA>     <NA>     <NA>     <NA>
# 4          <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>
# ...         ...          ...      ...      ...      ...      ...      ...
# 1224       <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>
# 1225       <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>
# 1226       <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>
# 1227       <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>
# 1228          0         1792      297      152      303      345      434
#
#         SY
# 0     2017
# 1     2017
# 2     2017
# 3     2017
# 4     2017
# ...    ...
# 1224  2017
# 1225  2017
# 1226  2017
# 1227  2017
# 1228  2017
#
# [1229 rows x 26 columns]

# %%
all_merged.to_csv("all_merged.csv", index=False)

# %%
all_merged_json = all_merged.to_json(orient='records')

# %%
json_file = open("all_merged.json", "w")
json_file.write(all_merged_json)
json_file.close()
