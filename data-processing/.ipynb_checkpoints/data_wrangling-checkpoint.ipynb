# %%
# Digital Equity

# %%
import pandas as pd
import numpy as np

# %%
course_enrollment = pd.read_csv('initial_data/CS-Course-Enrollment-2017.csv')

# %%
course_enrollment
# Out:
#      School Code                                           District  \
# 0          10405                                           Abington
# 1          10505                                           Abington
# 2          30025                                           Acushnet
# 3          30305                                           Acushnet
# 4          50303                                             Agawam
# ..           ...                                                ...
# 956     35040505  City on a Hill Charter Public School Dudley Sq...
# 957     35060505  Pioneer Charter School of Science II (PCSS-II)...
# 958     35070505  City on a Hill Charter Public School New Bedfo...
# 959     39020900  TEC Connections Academy Commonwealth Virtual S...
# 960            0                                      Massachusetts
#
#                                            School Name  # STUDENTS ENROLLED  \
# 0                                 Frolio Middle School                  322
# 1                                        Abington High                   20
# 2                           Acushnet Elementary School                    2
# 3                          Albert F Ford Middle School                  416
# 4                            Roberta G. Doering School                  498
# ..                                                 ...                  ...
# 956  City on a Hill Charter Public School Dudley Sq...                   53
# 957     Pioneer Charter School of Science II (PCSS-II)                  200
# 958   City on a Hill Charter Public School New Bedford                   76
# 959  TEC Connections Academy Commonwealth Virtual S...                  553
# 960                                      Massachusetts               238936
#
#      # STUDENTS ENROLLED PRIOR TO SECONDARY LEVEL  \
# 0                                             322
# 1                                               1
# 2                                               2
# 3                                             416
# 4                                             498
# ..                                            ...
# 956                                             0
# 957                                           140
# 958                                             0
# 959                                           451
# 960                                        204688
#
#      # STUDENTS ENROLLED AT SECONDARY LEVEL
# 0                                         0
# 1                                        19
# 2                                         0
# 3                                         0
# 4                                         0
# ..                                      ...
# 956                                      53
# 957                                      60
# 958                                      76
# 959                                     102
# 960                                   34364
#
# [961 rows x 6 columns]

# %%
course_enrollment = course_enrollment.drop(columns=["# STUDENTS ENROLLED PRIOR TO SECONDARY LEVEL", "# STUDENTS ENROLLED AT SECONDARY LEVEL"])

# %%
course_enrollment.dtypes
# Out:
# School Code             int64
# District               object
# School Name            object
# # STUDENTS ENROLLED     int64
# dtype: object

# %%
course_enrollment
# Out:
#      School Code                                           District  \
# 0          10405                                           Abington
# 1          10505                                           Abington
# 2          30025                                           Acushnet
# 3          30305                                           Acushnet
# 4          50303                                             Agawam
# ..           ...                                                ...
# 956     35040505  City on a Hill Charter Public School Dudley Sq...
# 957     35060505  Pioneer Charter School of Science II (PCSS-II)...
# 958     35070505  City on a Hill Charter Public School New Bedfo...
# 959     39020900  TEC Connections Academy Commonwealth Virtual S...
# 960            0                                      Massachusetts
#
#                                            School Name  # STUDENTS ENROLLED
# 0                                 Frolio Middle School                  322
# 1                                        Abington High                   20
# 2                           Acushnet Elementary School                    2
# 3                          Albert F Ford Middle School                  416
# 4                            Roberta G. Doering School                  498
# ..                                                 ...                  ...
# 956  City on a Hill Charter Public School Dudley Sq...                   53
# 957     Pioneer Charter School of Science II (PCSS-II)                  200
# 958   City on a Hill Charter Public School New Bedford                   76
# 959  TEC Connections Academy Commonwealth Virtual S...                  553
# 960                                      Massachusetts               238936
#
# [961 rows x 4 columns]

# %%
demographic = pd.read_csv('initial_data/AP-CS-Gender-Ethnicity.xlsx-2017.csv')

# %%
demographic
# Out:
#      ORG_CODE  School Code                                          DIST_NAME  \
# 0           9        90505                                            Andover
# 1          10       100505                                          Arlington
# 2          14       140505                                            Ashland
# 3          20       200505                                         Barnstable
# 4          23       230505                                            Bedford
# ..        ...          ...                                                ...
# 115       829      8290605      South Middlesex Regional Vocational Technical
# 116       852      8520605       Nashoba Valley Regional Vocational Technical
# 117       860      8600605           Pathfinder Regional Vocational Technical
# 118      3902     39020900  TEC Connections Academy Commonwealth Virtual S...
# 119         0            0                                      Massachusetts
#
#                                               SCH_NAME  STUDENTS_ENROLLED  \
# 0                                         Andover High                 41
# 1                                       Arlington High                 17
# 2                                         Ashland High                 23
# 3                                      Barnstable High                 20
# 4                                         Bedford High                  4
# ..                                                 ...                ...
# 115               Joseph P Keefe Technical High School                 12
# 116               Nashoba Valley Technical High School                  9
# 117                    Pathfinder Vocational Technical                 17
# 118  TEC Connections Academy Commonwealth Virtual S...                  1
# 119                                      Massachusetts               1976
#
#       AA   AS   HI  MR NA NH_PI    WH EcoDis SWD ELL FEMALE  MALE NONBINARY
# 0      1   14    1   2  0     0    23      1   0   0      4    37         0
# 1      0    1    1   1  0     1    13      1   1   0      2    15         0
# 2      0    1    1   0  0     0    21      0   1   0      4    19         0
# 3      0    4    3   0  0     0    13      4   0   0      3    17         0
# 4    NaN
# ..   ...  ...  ...  .. ..   ...   ...    ...  ..  ..    ...   ...       ...
# 115    0    0    3   1  0     0     8      3   1   0      5     7         0
# 116    0    0    0   1  0     0     8      0   1   0      1     8         0
# 117    0    0    2   1  1     0    13      5   0   0      5    12         0
# 118
# 119   93  334  113  55  2     3  1317    186  52  10    417  1499         1
#
# [120 rows x 18 columns]

# %%
demographic.dtypes
# Out:
# ORG_CODE              int64
# School Code           int64
# DIST_NAME            object
# SCH_NAME             object
# STUDENTS_ENROLLED     int64
# AA                   object
# AS                   object
# HI                   object
# MR                   object
# NA                   object
# NH_PI                object
# WH                   object
# EcoDis               object
# SWD                  object
# ELL                  object
# FEMALE               object
# MALE                 object
# NONBINARY            object
# dtype: object

# %%
demographic = demographic.drop(columns=['DIST_NAME', 'SCH_NAME'])

# %%
demographic
# Out:
#      ORG_CODE  School Code  STUDENTS_ENROLLED   AA   AS   HI  MR NA NH_PI  \
# 0           9        90505                 41    1   14    1   2  0     0
# 1          10       100505                 17    0    1    1   1  0     1
# 2          14       140505                 23    0    1    1   0  0     0
# 3          20       200505                 20    0    4    3   0  0     0
# 4          23       230505                  4  NaN
# ..        ...          ...                ...  ...  ...  ...  .. ..   ...
# 115       829      8290605                 12    0    0    3   1  0     0
# 116       852      8520605                  9    0    0    0   1  0     0
# 117       860      8600605                 17    0    0    2   1  1     0
# 118      3902     39020900                  1
# 119         0            0               1976   93  334  113  55  2     3
#
#        WH EcoDis SWD ELL FEMALE  MALE NONBINARY
# 0      23      1   0   0      4    37         0
# 1      13      1   1   0      2    15         0
# 2      21      0   1   0      4    19         0
# 3      13      4   0   0      3    17         0
# 4
# ..    ...    ...  ..  ..    ...   ...       ...
# 115     8      3   1   0      5     7         0
# 116     8      0   1   0      1     8         0
# 117    13      5   0   0      5    12         0
# 118
# 119  1317    186  52  10    417  1499         1
#
# [120 rows x 16 columns]

# %%
demographic["AA"] = pd.to_numeric(demographic["AA"], errors='coerce')
demographic["AS"] = pd.to_numeric(demographic["AS"], errors='coerce')
demographic["HI"] = pd.to_numeric(demographic["HI"], errors='coerce')
demographic["MR"] = pd.to_numeric(demographic["MR"], errors='coerce')
demographic["NA"] = pd.to_numeric(demographic["NA"], errors='coerce')
demographic["NH_PI"] = pd.to_numeric(demographic["NH_PI"], errors='coerce')
demographic["WH"] = pd.to_numeric(demographic["WH"], errors='coerce')
demographic["EcoDis"] = pd.to_numeric(demographic["EcoDis"], errors='coerce')
demographic["SWD"] = pd.to_numeric(demographic["SWD"], errors='coerce')
demographic["ELL"] = pd.to_numeric(demographic["ELL"], errors='coerce')
demographic["FEMALE"] = pd.to_numeric(demographic["FEMALE"], errors='coerce')
demographic["MALE"] = pd.to_numeric(demographic["MALE"], errors='coerce')
demographic["NONBINARY"] = pd.to_numeric(demographic["NONBINARY"], errors='coerce')

# %%
demographic["AA"] = demographic["AA"].astype("Int64")
demographic["AS"] = demographic["AS"].astype("Int64")
demographic["HI"] = demographic["HI"].astype("Int64")
demographic["MR"] = demographic["MR"].astype("Int64")
demographic["NA"] = demographic["NA"].astype("Int64")
demographic["NH_PI"] = demographic["NH_PI"].astype("Int64")
demographic["WH"] = demographic["WH"].astype("Int64")
demographic["EcoDis"] = demographic["EcoDis"].astype("Int64")
demographic["SWD"] = demographic["SWD"].astype("Int64")
demographic["ELL"] = demographic["ELL"].astype("Int64")
demographic["FEMALE"] = demographic["FEMALE"].astype("Int64")
demographic["MALE"] = demographic["MALE"].astype("Int64")
demographic["NONBINARY"] = demographic["NONBINARY"].astype("Int64")

# %%
demographic.dtypes
# Out:
# ORG_CODE             int64
# School Code          int64
# STUDENTS_ENROLLED    int64
# AA                   Int64
# AS                   Int64
# HI                   Int64
# MR                   Int64
# NA                   Int64
# NH_PI                Int64
# WH                   Int64
# EcoDis               Int64
# SWD                  Int64
# ELL                  Int64
# FEMALE               Int64
# MALE                 Int64
# NONBINARY            Int64
# dtype: object

# %%
scores = pd.read_csv('initial_data/2017-AP-Performance.csv')

# %%
scores
# Out:
#                                            School Name    School Code  \
# 0    Acton-Boxborough - Acton-Boxborough Regional High        6000505
# 1    Advanced Math and Science Academy Charter (Dis...        4300305
# 2               Amherst-Pelham - Amherst Regional High        6050505
# 3                               Andover - Andover High          90505
# 4                           Arlington - Arlington High         100505
# ..                                                 ...            ...
# 140                    Winthrop - Winthrop High School        3460505
# 141                  Worcester - Doherty Memorial High        3480512
# 142                   Worcester - South High Community        3480520
# 143               Worcester - Worcester Technical High        3480605
# 144                                      Massachusetts  Massachusetts
#
#      Tests Taken  Score=1  Score=2  Score=3  Score=4  Score=5  % Score 1-2  \
# 0             40      0.0      0.0      3.0     13.0     24.0          0.0
# 1             35      2.0      1.0      8.0     15.0      9.0          8.6
# 2              1      NaN      NaN      NaN      NaN      NaN          NaN
# 3             30      1.0      1.0      2.0     10.0     16.0          6.7
# 4             18      1.0      1.0      3.0      6.0      7.0         11.1
# ..           ...      ...      ...      ...      ...      ...          ...
# 140            1      NaN      NaN      NaN      NaN      NaN          NaN
# 141            9      NaN      NaN      NaN      NaN      NaN          NaN
# 142            1      NaN      NaN      NaN      NaN      NaN          NaN
# 143           23     10.0      4.0      8.0      1.0      0.0         60.9
# 144         1697    283.0    172.0    281.0    314.0    349.0       2126.5
#
#      % Score 3-5
# 0          100.0
# 1           91.4
# 2            NaN
# 3           93.3
# 4           88.9
# ..           ...
# 140          NaN
# 141          NaN
# 142          NaN
# 143         39.1
# 144       3773.8
#
# [145 rows x 10 columns]

# %%
scores = scores.drop(columns=['School Name', '% Score 1-2', '% Score 3-5'])

# %%
scores["School Code"] = scores["School Code"].astype("Int64")

# %%
scores.dtypes
# Out:
# School Code      Int64
# Tests Taken      int64
# Score=1        float64
# Score=2        float64
# Score=3        float64
# Score=4        float64
# Score=5        float64
# dtype: object

# %%
all_merged = course_enrollment.merge(demographic, how='left', on='School Code').merge(scores, how='left', on='School Code')

# %%
all_merged
# Out:
#      School Code                                           District  \
# 0          10405                                           Abington
# 1          10505                                           Abington
# 2          30025                                           Acushnet
# 3          30305                                           Acushnet
# 4          50303                                             Agawam
# ..           ...                                                ...
# 956     35040505  City on a Hill Charter Public School Dudley Sq...
# 957     35060505  Pioneer Charter School of Science II (PCSS-II)...
# 958     35070505  City on a Hill Charter Public School New Bedfo...
# 959     39020900  TEC Connections Academy Commonwealth Virtual S...
# 960            0                                      Massachusetts
#
#                                            School Name  # STUDENTS ENROLLED  \
# 0                                 Frolio Middle School                  322
# 1                                        Abington High                   20
# 2                           Acushnet Elementary School                    2
# 3                          Albert F Ford Middle School                  416
# 4                            Roberta G. Doering School                  498
# ..                                                 ...                  ...
# 956  City on a Hill Charter Public School Dudley Sq...                   53
# 957     Pioneer Charter School of Science II (PCSS-II)                  200
# 958   City on a Hill Charter Public School New Bedford                   76
# 959  TEC Connections Academy Commonwealth Virtual S...                  553
# 960                                      Massachusetts               238936
#
#      ORG_CODE  STUDENTS_ENROLLED    AA    AS    HI    MR  ...   ELL  FEMALE  \
# 0         NaN                NaN  <NA>  <NA>  <NA>  <NA>  ...  <NA>    <NA>
# 1         NaN                NaN  <NA>  <NA>  <NA>  <NA>  ...  <NA>    <NA>
# 2         NaN                NaN  <NA>  <NA>  <NA>  <NA>  ...  <NA>    <NA>
# 3         NaN                NaN  <NA>  <NA>  <NA>  <NA>  ...  <NA>    <NA>
# 4         NaN                NaN  <NA>  <NA>  <NA>  <NA>  ...  <NA>    <NA>
# ..        ...                ...   ...   ...   ...   ...  ...   ...     ...
# 956       NaN                NaN  <NA>  <NA>  <NA>  <NA>  ...  <NA>    <NA>
# 957       NaN                NaN  <NA>  <NA>  <NA>  <NA>  ...  <NA>    <NA>
# 958       NaN                NaN  <NA>  <NA>  <NA>  <NA>  ...  <NA>    <NA>
# 959    3902.0                1.0  <NA>  <NA>  <NA>  <NA>  ...  <NA>    <NA>
# 960       0.0             1976.0    93   334   113    55  ...    10     417
#
#      MALE  NONBINARY  Tests Taken  Score=1  Score=2  Score=3  Score=4  Score=5
# 0    <NA>       <NA>          NaN      NaN      NaN      NaN      NaN      NaN
# 1    <NA>       <NA>          NaN      NaN      NaN      NaN      NaN      NaN
# 2    <NA>       <NA>          NaN      NaN      NaN      NaN      NaN      NaN
# 3    <NA>       <NA>          NaN      NaN      NaN      NaN      NaN      NaN
# 4    <NA>       <NA>          NaN      NaN      NaN      NaN      NaN      NaN
# ..    ...        ...          ...      ...      ...      ...      ...      ...
# 956  <NA>       <NA>          NaN      NaN      NaN      NaN      NaN      NaN
# 957  <NA>       <NA>          NaN      NaN      NaN      NaN      NaN      NaN
# 958  <NA>       <NA>          NaN      NaN      NaN      NaN      NaN      NaN
# 959  <NA>       <NA>          NaN      NaN      NaN      NaN      NaN      NaN
# 960  1499          1          NaN      NaN      NaN      NaN      NaN      NaN
#
# [961 rows x 25 columns]

# %%
all_merged.dtypes
# Out:
# School Code              int64
# District                object
# School Name             object
# # STUDENTS ENROLLED      int64
# ORG_CODE               float64
# STUDENTS_ENROLLED      float64
# AA                       Int64
# AS                       Int64
# HI                       Int64
# MR                       Int64
# NA                       Int64
# NH_PI                    Int64
# WH                       Int64
# EcoDis                   Int64
# SWD                      Int64
# ELL                      Int64
# FEMALE                   Int64
# MALE                     Int64
# NONBINARY                Int64
# Tests Taken            float64
# Score=1                float64
# Score=2                float64
# Score=3                float64
# Score=4                float64
# Score=5                float64
# dtype: object

# %%
all_merged = all_merged.astype({"STUDENTS_ENROLLED": "Int64", "ORG_CODE": "Int64"})

# %%
all_merged["Tests Taken"] = all_merged["Tests Taken"].astype("Int64")
all_merged["Score=1"] = all_merged["Score=1"].astype("Int64")
all_merged["Score=2"] = all_merged["Score=2"].astype("Int64")
all_merged["Score=3"] = all_merged["Score=3"].astype("Int64")
all_merged["Score=4"] = all_merged["Score=4"].astype("Int64")
all_merged["Score=5"] = all_merged["Score=5"].astype("Int64")

# %%
all_merged.dtypes
# Out:
# School Code             int64
# District               object
# School Name            object
# # STUDENTS ENROLLED     int64
# ORG_CODE                Int64
# STUDENTS_ENROLLED       Int64
# AA                      Int64
# AS                      Int64
# HI                      Int64
# MR                      Int64
# NA                      Int64
# NH_PI                   Int64
# WH                      Int64
# EcoDis                  Int64
# SWD                     Int64
# ELL                     Int64
# FEMALE                  Int64
# MALE                    Int64
# NONBINARY               Int64
# Tests Taken             Int64
# Score=1                 Int64
# Score=2                 Int64
# Score=3                 Int64
# Score=4                 Int64
# Score=5                 Int64
# dtype: object

# %%
all_merged['SY'] = 2017

# %%
all_merged
# Out:
#      School Code                                           District  \
# 0          10405                                           Abington
# 1          10505                                           Abington
# 2          30025                                           Acushnet
# 3          30305                                           Acushnet
# 4          50303                                             Agawam
# ..           ...                                                ...
# 956     35040505  City on a Hill Charter Public School Dudley Sq...
# 957     35060505  Pioneer Charter School of Science II (PCSS-II)...
# 958     35070505  City on a Hill Charter Public School New Bedfo...
# 959     39020900  TEC Connections Academy Commonwealth Virtual S...
# 960            0                                      Massachusetts
#
#                                            School Name  # STUDENTS ENROLLED  \
# 0                                 Frolio Middle School                  322
# 1                                        Abington High                   20
# 2                           Acushnet Elementary School                    2
# 3                          Albert F Ford Middle School                  416
# 4                            Roberta G. Doering School                  498
# ..                                                 ...                  ...
# 956  City on a Hill Charter Public School Dudley Sq...                   53
# 957     Pioneer Charter School of Science II (PCSS-II)                  200
# 958   City on a Hill Charter Public School New Bedford                   76
# 959  TEC Connections Academy Commonwealth Virtual S...                  553
# 960                                      Massachusetts               238936
#
#      ORG_CODE  STUDENTS_ENROLLED    AA    AS    HI    MR  ...  FEMALE  MALE  \
# 0        <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 1        <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 2        <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 3        <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 4        <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# ..        ...                ...   ...   ...   ...   ...  ...     ...   ...
# 956      <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 957      <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 958      <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 959      3902                  1  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 960         0               1976    93   334   113    55  ...     417  1499
#
#      NONBINARY  Tests Taken  Score=1  Score=2  Score=3  Score=4  Score=5    SY
# 0         <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>  2017
# 1         <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>  2017
# 2         <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>  2017
# 3         <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>  2017
# 4         <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>  2017
# ..         ...          ...      ...      ...      ...      ...      ...   ...
# 956       <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>  2017
# 957       <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>  2017
# 958       <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>  2017
# 959       <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>  2017
# 960          1         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>  2017
#
# [961 rows x 26 columns]

# %%
all_merged
# Out:
#      School Code                                           District  \
# 0          10405                                           Abington
# 1          10505                                           Abington
# 2          30025                                           Acushnet
# 3          30305                                           Acushnet
# 4          50303                                             Agawam
# ..           ...                                                ...
# 956     35040505  City on a Hill Charter Public School Dudley Sq...
# 957     35060505  Pioneer Charter School of Science II (PCSS-II)...
# 958     35070505  City on a Hill Charter Public School New Bedfo...
# 959     39020900  TEC Connections Academy Commonwealth Virtual S...
# 960            0                                      Massachusetts
#
#                                            School Name  # STUDENTS ENROLLED  \
# 0                                 Frolio Middle School                  322
# 1                                        Abington High                   20
# 2                           Acushnet Elementary School                    2
# 3                          Albert F Ford Middle School                  416
# 4                            Roberta G. Doering School                  498
# ..                                                 ...                  ...
# 956  City on a Hill Charter Public School Dudley Sq...                   53
# 957     Pioneer Charter School of Science II (PCSS-II)                  200
# 958   City on a Hill Charter Public School New Bedford                   76
# 959  TEC Connections Academy Commonwealth Virtual S...                  553
# 960                                      Massachusetts               238936
#
#      ORG_CODE  STUDENTS_ENROLLED    AA    AS    HI    MR  ...  FEMALE  MALE  \
# 0        <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 1        <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 2        <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 3        <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 4        <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# ..        ...                ...   ...   ...   ...   ...  ...     ...   ...
# 956      <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 957      <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 958      <NA>               <NA>  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 959      3902                  1  <NA>  <NA>  <NA>  <NA>  ...    <NA>  <NA>
# 960         0               1976    93   334   113    55  ...     417  1499
#
#      NONBINARY  Tests Taken  Score=1  Score=2  Score=3  Score=4  Score=5    SY
# 0         <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>  2017
# 1         <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>  2017
# 2         <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>  2017
# 3         <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>  2017
# 4         <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>  2017
# ..         ...          ...      ...      ...      ...      ...      ...   ...
# 956       <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>  2017
# 957       <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>  2017
# 958       <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>  2017
# 959       <NA>         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>  2017
# 960          1         <NA>     <NA>     <NA>     <NA>     <NA>     <NA>  2017
#
# [961 rows x 26 columns]

# %%
all_merged.to_csv("all_merged.csv", index=False)

# %%
all_merged_json = all_merged.to_json(orient='records')

# %%
json_file = open("all_merged.json", "w")
json_file.write(all_merged_json)
json_file.close()
